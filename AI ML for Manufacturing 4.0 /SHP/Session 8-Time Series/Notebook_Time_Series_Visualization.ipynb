# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Ganti path dengan path file CSV di Google Drive Anda
file_path = '/content/drive/MyDrive/Dataset/TimeSeries.csv'

# Membaca file CSV ke dalam dataframe
df = pd.read_csv(file_path)

# Menampilkan beberapa baris pertama dari dataframe
print(df.head())
# Out:
#          Date     Value
# 0  01-07-1991  3.526591
# 1  01-08-1991  3.180891
# 2  01-09-1991  3.252221
# 3  01-10-1991  3.611003
# 4  01-11-1991  3.565869

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    204 non-null    object
#  1   Value   204 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# **Prompt chatgpt:**
#
# visualisasikan dataset df dengan data berupa time series dalam bentuk scatter plot dengan info di bawah:
#
# Data columns (total 2 columns):
#
#  /#   Column  Non-Null Count  Dtype
#
# ---  ------  --------------  -----
#
#  0   Date    204 non-null    object
#
#  1   Value   204 non-null    float64

# %%
import matplotlib.pyplot as plt

# Konversi kolom 'Date' menjadi format datetime
df['Date'] = pd.to_datetime(df['Date'])

# Menyiapkan plot
plt.figure(figsize=(12, 6))

# Membuat scatter plot
plt.scatter(df['Date'], df['Value'], color='b', alpha=0.5)

# Menambahkan judul dan label sumbu
plt.title('Scatter Plot of Time Series Data', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Value', fontsize=12)

# Menampilkan plot
plt.show()

# %%
df.plot()
plt.grid()
plt.show()
