# %% [markdown]
# Kode-kode ini dapat digunakan untuk memahami distribusi data tekanan sesudah pompa dalam industri manufaktur, serta membantu dalam mengidentifikasi dan memahami probabilitas terkait dengan nilai tekanan tertentu atau rentang nilai tertentu. Hal ini dapat digunakan untuk melakukan pemeliharaan peralatan, mengoptimalkan proses manufaktur, dan memastikan kualitas produk yang dihasilkan.

# %% [markdown]
# # Sel 1: Pada sel ini, kita akan memasang paket-paket yang diperlukan untuk analisis data.
#
# Prompt: Tulislah kode Python untuk menginstal paket yang diperlukan untuk analisis data.

# %% [markdown]
# #Sel 2: Pada sel ini, kita akan mengimpor pustaka-pustaka yang akan digunakan dalam analisis data.
#
# Prompt: Tulislah kode Python untuk mengimpor pustaka yang diperlukan untuk analisis data.

# %% [markdown]
# # Sel 3: Pada sel ini, kita akan mengatur palet warna untuk visualisasi.
#
# Prompt: Tulislah kode Python untuk mengatur palet warna untuk visualisasi.

# %% [markdown]
# #Sel 4: Pada sel ini, kita akan membuat data set fiksi yang merepresentasikan tekanan sesudah pompa.
#
# Prompt: Tulislah kode Python untuk membuat data set fiksi yang merepresentasikan tekanan sesudah pompa.

# %% [markdown]
# # Sel 5: Pada sel ini, kita akan menampilkan 12 sampel pertama dari data tekanan.
#
# Prompt: Tulislah kode Python untuk menampilkan 12 sampel pertama dari data tekanan.

# %%
# Out:
# array([38.48094801, 55.85982374, 41.1747908 , 40.91516951, 49.16693998,
#        56.0371513 , 37.12804936, 46.45419586, 44.99798848, 48.03890961,
#        41.16782993, 48.60873415])

# %% [markdown]
# # Sel 6: Pada sel ini, kita akan memvisualisasikan fungsi densitas probabilitas (PDF) dan area di bawah kurva yang sesuai dengan nilai tertentu.
#
# Prompt: Tulislah kode Python untuk memvisualisasikan fungsi densitas probabilitas (PDF) dan area di bawah kurva yang sesuai dengan nilai tertentu.

# %%
# Out:
# <ipython-input-6-8e138376787f>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tekanan_pompa, label='Tekanan Pompa', kde=False, fit=stats.norm, color='w')

# %% [markdown]
# # Sel 7: Pada sel ini, kita akan memvisualisasikan area di bawah kurva yang mengandung probabilitas memiliki tekanan lebih dari 47.
#
# Prompt: Tulislah kode Python untuk memvisualisasikan area di bawah kurva yang mengandung probabilitas memiliki tekanan lebih dari 47.

# %%
# Out:
# <ipython-input-10-5a2729443a11>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tekanan_pompa, label='Tekanan Pompa', kde=False, fit=stats.norm, color='w')

# %% [markdown]
# # Sel 8: Pada sel ini, kita akan memvisualisasikan area di bawah kurva yang berada di antara dua nilai tertentu, yaitu 47 dan 52.
#
# Prompt: Tulislah kode Python untuk memvisualisasikan area di bawah kurva yang berada di antara dua nilai tertentu.

# %%
# Out:
# <ipython-input-7-ea08bd4a8e10>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tekanan_pompa, label='Tekanan Pompa', kde=False, fit=stats.norm, color='w')
