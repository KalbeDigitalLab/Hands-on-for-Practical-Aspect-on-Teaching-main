# %% [markdown]
# #Dataset Predictive Maintanance
#
# * Predictive maintenance adalah pendekatan yang digunakan dalam **pemeliharaan peralatan dan mesin industri** yang melibatkan penggunaan data dan analisis prediktif untuk **meramalkan kapan peralatan akan mengalami kerusakan atau kegagalan** sehingga **tindakan perawatan dapat diambil sebelum kegagalan tersebut terjadi.**
# * Dataset predictive maintenance adalah kumpulan data yang digunakan untuk **melatih model prediktif** yang dapat **memprediksi kapan peralatan akan memerlukan perawatan.**
# * Dataset predictive maintenance biasanya mencakup data yang mencerminkan **kondisi peralatan, informasi waktu pemeliharaan sebelumnya,** dan informasi lainnya yang dapat digunakan untuk mengembangkan model prediktif.
# * Tujuan utama dari penggunaan dataset ini adalah untuk **meningkatkan efisiensi operasional dan mengurangi downtime mesin dengan melakukan perawatan yang lebih tepat waktu.**
# * Dataset predictive maintenance sering digunakan dalam berbagai industri, termasuk manufaktur, perawatan fasilitas, energi, dan transportasi. Mereka membantu organisasi menghindari kerusakan yang tidak terduga dan mengoptimalkan jadwal perawatan, yang pada akhirnya dapat menghemat waktu dan biaya.

# %% [markdown]
# # Penjelasan Fitur-fitur
#
# 1. UDI (Unique Device Identifier)-Metadata:
#     - Ini adalah kolom yang berisi identifikasi unik untuk setiap perangkat atau unit dalam dataset. Ini adalah atribut yang digunakan untuk mengidentifikasi dan melacak perangkat secara individu.
# 2. Type-Feature:
#     - Ini adalah tipe perangkat atau unit yang diamati. Nilainya dapat berupa H (High), L (Low), atau M (Medium), yang mungkin mencerminkan karakteristik atau kelas peralatan tertentu.
# 3. Air Temperature [K]-Feature:
#     - Ini adalah kolom yang mencatat suhu udara dalam Kelvin (K) yang terkait dengan perangkat atau unit yang diamati.
# 4. Process Temperature [K]-Feature:
#     - Ini adalah kolom yang mencatat suhu proses dalam Kelvin (K) yang terkait dengan perangkat atau unit yang diamati.
# 5. Rotational Speed [rpm]-Feature:
#     - Ini adalah kolom yang mencatat kecepatan rotasi dalam revolusi per menit (rpm) yang terkait dengan perangkat atau unit.
# 6. Torque [Nm]-Feature:
#     - Ini adalah kolom yang mencatat torsi yang dihasilkan oleh perangkat atau unit dalam Newton-meter (Nm).
# 7. Target-Target:
#     - Ini adalah kolom target yang akan diprediksi oleh model. Nilainya dapat berupa 0 atau 1, yang mungkin mencerminkan apakah perangkat akan mengalami kegagalan (1) atau tidak (0).
# 8. Failure Type-Target:
#     - Ini adalah kolom yang mencatat jenis kegagalan yang mungkin dialami oleh perangkat. Nilainya dapat mencakup berbagai jenis kegagalan, seperti Heat Dissipation Failure, No Failure, Power Failure, Random Failures, Tool Wear Failure, dan Overstrain Failure.
# 9. Product ID-Metadata:
#     - Ini adalah kolom yang mencatat identifikasi produk yang terkait dengan perangkat atau unit dalam dataset.

# %% [markdown]
# Prompt: Cara menghubungkan google colab dengan google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Prompt: Beri kode untuk membaca dataset

# %%
import pandas as pd

# Gantilah 'nama_file.csv' dengan nama file CSV yang sesuai
nama_file = '/content/drive/MyDrive/Dataset/predictive_maintenance.csv'

# Gunakan perintah berikut untuk membaca dataset CSV
data = pd.read_csv(nama_file)

# Tampilkan beberapa baris awal dataset
data.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %% [markdown]
# Prompt: Beri kode untuk menampilkan info dataframe dengan nama dataframe "data"

# %%
# Jika DataFrame Anda sudah dibaca sebelumnya dan disimpan dalam variabel 'data'
# Anda dapat menampilkan informasi tentang DataFrame tersebut seperti ini:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB

# %% [markdown]
# Prompt: Beri kode untuk menampilkan distribusi fitur-fitur berikut, Type, Air temperature [K] , Process temperature [K], Rotational speed [rpm], Torque [Nm], Tool wear [min], Target, Failure Type

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Misalkan 'data' adalah DataFrame yang berisi dataset Anda.

# Visualisasi distribusi fitur "Type"
plt.figure(figsize=(8, 4))
sns.countplot(data=data, x='Type')
plt.title('Distribusi Fitur "Type"')
plt.show()

# Visualisasi distribusi fitur "Air temperature [K]"
plt.figure(figsize=(8, 4))
sns.histplot(data=data, x='Air temperature [K]', kde=True)
plt.title('Distribusi Fitur "Air temperature [K]"')
plt.show()

# Visualisasi distribusi fitur "Process temperature [K]"
plt.figure(figsize=(8, 4))
sns.histplot(data=data, x='Process temperature [K]', kde=True)
plt.title('Distribusi Fitur "Process temperature [K]"')
plt.show()

# Visualisasi distribusi fitur "Rotational speed [rpm]"
plt.figure(figsize=(8, 4))
sns.histplot(data=data, x='Rotational speed [rpm]', kde=True)
plt.title('Distribusi Fitur "Rotational speed [rpm]"')
plt.show()

# Visualisasi distribusi fitur "Torque [Nm]"
plt.figure(figsize=(8, 4))
sns.histplot(data=data, x='Torque [Nm]', kde=True)
plt.title('Distribusi Fitur "Torque [Nm]"')
plt.show()

# Visualisasi distribusi fitur "Tool wear [min]"
plt.figure(figsize=(8, 4))
sns.histplot(data=data, x='Tool wear [min]', kde=True)
plt.title('Distribusi Fitur "Tool wear [min]"')
plt.show()

# Visualisasi distribusi fitur "Target"
plt.figure(figsize=(8, 4))
sns.countplot(data=data, x='Target')
plt.title('Distribusi Fitur "Target"')
plt.show()

# Visualisasi distribusi fitur "Failure Type"
plt.figure(figsize=(10, 4))
sns.countplot(data=data, x='Failure Type', order=data['Failure Type'].value_counts().index)
plt.title('Distribusi Fitur "Failure Type"')
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# Prompt: Beri kode untuk menampilkan distribusi fitur Failure Type (No Failure, Heat Dissipation Failure, Power Failure, Overstrain Failure, Tool Wear Failure, dan Rando Failures) dengan meninggalkan data "No Failure".

# %%
# Misalkan 'data' adalah DataFrame yang berisi dataset Anda.

# Filter data yang bukan "No Failure"
filtered_data = data[data['Failure Type'] != 'No Failure']

# Visualisasi distribusi fitur "Failure Type" yang tidak termasuk "No Failure"
plt.figure(figsize=(10, 4))
sns.countplot(data=filtered_data, x='Failure Type', order=filtered_data['Failure Type'].value_counts().index)
plt.title('Distribusi Fitur "Failure Type" (Tanpa "No Failure")')
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# Prompt: Beri kode untuk menampilkan boxplot fitur-fitur berikut, Air temperature [K] , Process temperature [K], Rotational speed [rpm], Torque [Nm], Tool wear [min]

# %%
# Misalkan 'data' adalah DataFrame yang berisi dataset Anda.

# Pilih kolom yang ingin Anda tampilkan dalam boxplot
selected_features = ['Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']

# Visualisasi boxplot untuk setiap fitur
plt.figure(figsize=(14, 8))

# Gunakan Seaborn untuk plot boxplot
sns.boxplot(data=data[selected_features], orient='v', palette='Set2')

plt.title('Boxplot of Selected Features')
plt.ylabel('Value')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Prompt: Beri kode untuk menampilkan boxplot fitur-fitur berikut, Air temperature [K] , Process temperature [K], Rotational speed [rpm], Torque [Nm], Tool wear [min] dengan grafik boxplot terpisah untuk masing-masing fitur.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Misalkan 'data' adalah DataFrame yang berisi dataset Anda.

# Pilih kolom yang ingin Anda tampilkan dalam boxplot
selected_features = ['Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']

# Visualisasi boxplot terpisah untuk setiap fitur
plt.figure(figsize=(14, 10))

# Loop melalui setiap fitur dan buat boxplot terpisah
for i, feature in enumerate(selected_features):
    plt.subplot(3, 2, i + 1)  # 3 baris, 2 kolom, plot ke-i
    sns.boxplot(data=data[feature], orient='v', palette='Set2')
    plt.title(f'Boxplot of {feature}')
    plt.ylabel('Value')
    plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# Prompt: Beri kode untuk menampilkan boxplot fitur-fitur berikut, Air temperature [K] , Process temperature [K], Rotational speed [rpm], Torque [Nm], Tool wear [min] dengan grafik boxplot terpisah untuk masing-masing fitur, dan ditampilkan secara horizontal.

# %%
# Misalkan 'data' adalah DataFrame yang berisi dataset Anda.

# Pilih kolom yang ingin Anda tampilkan dalam boxplot
selected_features = ['Air temperature [K]', 'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']

# Visualisasi boxplot terpisah untuk setiap fitur (secara horizontal)
plt.figure(figsize=(12, 8))

# Loop melalui setiap fitur dan buat boxplot terpisah
for i, feature in enumerate(selected_features):
    plt.subplot(2, 3, i + 1)  # 2 baris, 3 kolom, plot ke-i
    sns.boxplot(data=data[feature], orient='h', palette='Set2')
    plt.title(f'Boxplot of {feature}')
    plt.xlabel('Value')
    plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# Prompt: Beri kode untuk menampilkan probability of 'Target' at given 'Air temperature [K]'

# %%
# Misalkan 'data' adalah DataFrame yang berisi dataset Anda.

# Membuat rangkaian nilai 'Air temperature [K]'
air_temperature_values = data['Air temperature [K]'].unique()

# Menghitung Probability of 'Target' pada setiap nilai 'Air temperature [K]'
probabilities_target_0 = []
probabilities_target_1 = []

for temp_value in air_temperature_values:
    # Filter data berdasarkan 'Air temperature [K]' tertentu
    data_temp = data[data['Air temperature [K]'] == temp_value]

    # Menghitung probability 'Target' pada nilai 'Air temperature [K]' tersebut
    probability_target_1 = len(data_temp[data_temp['Target'] == 1]) / len(data_temp)
    probability_target_0 = len(data_temp[data_temp['Target'] == 0]) / len(data_temp)

    probabilities_target_1.append(probability_target_1)
    probabilities_target_0.append(probability_target_0)

# Visualisasi Probability of 'Target' pada 'Air temperature [K]'
plt.figure(figsize=(12, 6))

plt.plot(air_temperature_values, probabilities_target_0, label='Target 0', marker='o', linestyle='-')
plt.plot(air_temperature_values, probabilities_target_1, label='Target 1', marker='o', linestyle='-')

plt.xlabel('Air temperature [K]')
plt.ylabel('Probability of Target')
plt.title('Probability of Target at Given Air temperature [K]')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Prompt: Beri kode untuk menampilkan probability of 'Target' at given 'Tool wear [min]' bin width 50

# %%
# Misalkan 'data' adalah DataFrame yang berisi dataset Anda.

# Tentukan lebar bin (50 dalam kasus ini)
bin_width = 50

# Membuat range bin
bins = list(range(0, max(data['Tool wear [min]']) + bin_width, bin_width))

# Menghitung Probability of 'Target' pada setiap bin
probabilities_target_0 = []
probabilities_target_1 = []

for i in range(len(bins) - 1):
    bin_start = bins[i]
    bin_end = bins[i + 1]

    # Filter data yang berada dalam bin tertentu
    data_in_bin = data[(data['Tool wear [min]'] >= bin_start) & (data['Tool wear [min]'] < bin_end)]

    # Menghitung probability 'Target' pada bin tersebut
    probability_target_1 = len(data_in_bin[data_in_bin['Target'] == 1]) / len(data_in_bin)
    probability_target_0 = len(data_in_bin[data_in_bin['Target'] == 0]) / len(data_in_bin)

    probabilities_target_0.append(probability_target_0)
    probabilities_target_1.append(probability_target_1)

# Visualisasi Probability of 'Target' pada setiap bin
plt.figure(figsize=(12, 6))

plt.plot(bins[:-1], probabilities_target_0, label='Target 0', marker='o', linestyle='-')
plt.plot(bins[:-1], probabilities_target_1, label='Target 1', marker='o', linestyle='-')

plt.xlabel('Tool wear [min]')
plt.ylabel('Probability')
plt.title('Probability of Target at Given Tool wear [min] (Bin Width 50)')
plt.legend()
plt.grid(True)
plt.show()
